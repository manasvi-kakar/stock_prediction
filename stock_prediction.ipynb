# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")
sp500["Tomorrow"] = sp500["Close"].shift(-1)
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-07-18 00:00:00-04:00  6312.950195  6315.609863  6285.270020  6296.790039
# 2025-07-21 00:00:00-04:00  6304.740234  6336.080078  6303.790039  6305.600098
# 2025-07-22 00:00:00-04:00  6306.600098  6316.120117  6281.709961  6309.620117
# 2025-07-23 00:00:00-04:00  6326.899902  6360.640137  6317.490234  6358.910156
# 2025-07-24 00:00:00-04:00  6368.600098  6381.310059  6360.569824  6363.350098
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-07-11 00:00:00-04:00', '2025-07-14 00:00:00-04:00',
#                '2025-07-15 00:00:00-04:00', '2025-07-16 00:00:00-04:00',
#                '2025-07-17 00:00:00-04:00', '2025-07-18 00:00:00-04:00',
#                '2025-07-21 00:00:00-04:00', '2025-07-22 00:00:00-04:00',
#                '2025-07-23 00:00:00-04:00', '2025-07-24 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24506, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-07-18 00:00:00-04:00  6312.950195  6315.609863  6285.270020  6296.790039
# 2025-07-21 00:00:00-04:00  6304.740234  6336.080078  6303.790039  6305.600098
# 2025-07-22 00:00:00-04:00  6306.600098  6316.120117  6281.709961  6309.620117
# 2025-07-23 00:00:00-04:00  6326.899902  6360.640137  6317.490234  6358.910156
# 2025-07-24 00:00:00-04:00  6368.600098  6381.310059  6360.569824  6363.350098
#
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-07-18 00:00:00-04:00  6312.950195  6315.609863  6285.270020  6296.790039
# 2025-07-21 00:00:00-04:00  6304.740234  6336.080078  6303.790039  6305.600098
# 2025-07-22 00:00:00-04:00  6306.600098  6316.120117  6281.709961  6309.620117
# 2025-07-23 00:00:00-04:00  6326.899902  6360.640137  6317.490234  6358.910156
# 2025-07-24 00:00:00-04:00  6368.600098  6381.310059  6360.569824  6363.350098
#
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2025-07-18 00:00:00-04:00  6312.950195  6315.609863  6285.270020  6296.790039
# 2025-07-21 00:00:00-04:00  6304.740234  6336.080078  6303.790039  6305.600098
# 2025-07-22 00:00:00-04:00  6306.600098  6316.120117  6281.709961  6309.620117
# 2025-07-23 00:00:00-04:00  6326.899902  6360.640137  6317.490234  6358.910156
# 2025-07-24 00:00:00-04:00  6368.600098  6381.310059  6360.569824  6363.350098
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=200, min_samples_split=10,max_depth=10, random_state=1)
train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=10, n_estimators=200,
#                        random_state=1)

# %%
from sklearn.metrics import precision_score
preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.5616438356164384

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []
    
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    3366
# 0    3090
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5347593582887701

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.536865
# 0    0.463135
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()

    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

    new_predictors += [ratio_column, trend_column]

# %%
predictors = ["Close", "Volume", "Open", "High", "Low"] + new_predictors

# %%
for lag in range(1, 6):
    lag_col = f"Close_Lag_{lag}"
    sp500[lag_col] = sp500["Close"].shift(lag)
    predictors.append(lag_col)

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2025-07-17 00:00:00-04:00  6263.399902  6304.689941  6262.270020  6297.359863
# 2025-07-18 00:00:00-04:00  6312.950195  6315.609863  6285.270020  6296.790039
# 2025-07-21 00:00:00-04:00  6304.740234  6336.080078  6303.790039  6305.600098
# 2025-07-22 00:00:00-04:00  6306.600098  6316.120117  6281.709961  6309.620117
# 2025-07-23 00:00:00-04:00  6326.899902  6360.640137  6317.490234  6358.910156
#
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds>=.6] = 1
    preds[preds<.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    4585
# 1.0     870
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5712643678160919

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Safely zip features and importances
features = predictors
feature_importances = model.feature_importances_

importance_df = pd.DataFrame(
    list(zip(features, feature_importances)),
    columns=["Feature", "Importance"]
).sort_values(by="Importance", ascending=False)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x="Importance", y="Feature", data=importance_df)
plt.title("Feature Importance (Random Forest)")
plt.tight_layout()
plt.savefig("feature_importance.png", dpi=300)
plt.show()

# %%
# Ensure timezone-naive index for test data
test_naive_index = test.index.tz_localize(None)

# Create mask for dates present in sp500
mask = test_naive_index.isin(sp500.index)

# Filter test data to include only valid dates
X_test = test.loc[mask].copy()  # Use .copy() to avoid SettingWithCopyWarning
y_true = test.loc[mask, "Target"]

# RECREATE MISSING ENGINEERED FEATURES
# Use .loc for all assignments to avoid SettingWithCopyWarning

# 1. Close ratios
X_test.loc[:, 'Close_Ratio_2'] = X_test['Close'].pct_change(2)
X_test.loc[:, 'Close_Ratio_5'] = X_test['Close'].pct_change(5)
X_test.loc[:, 'Close_Ratio_60'] = X_test['Close'].pct_change(60)
X_test.loc[:, 'Close_Ratio_250'] = X_test['Close'].pct_change(250)
X_test.loc[:, 'Close_Ratio_1000'] = X_test['Close'].pct_change(1000)

# 2. Trends (rolling window statistics)
X_test.loc[:, 'Trend_2'] = X_test['Close'].rolling(2).mean()
X_test.loc[:, 'Trend_5'] = X_test['Close'].rolling(5).mean()
X_test.loc[:, 'Trend_60'] = X_test['Close'].rolling(60).mean()
X_test.loc[:, 'Trend_250'] = X_test['Close'].rolling(250).mean()
X_test.loc[:, 'Trend_1000'] = X_test['Close'].rolling(1000).mean()

# Fill NaN values strategically
X_test = X_test.fillna({
    'Close_Ratio_2': 0, 'Close_Ratio_5': 0, 'Close_Ratio_60': 0, 
    'Close_Ratio_250': 0, 'Close_Ratio_1000': 0,
    'Trend_2': X_test['Close'], 'Trend_5': X_test['Close'],
    'Trend_60': X_test['Close'], 'Trend_250': X_test['Close'],
    'Trend_1000': X_test['Close']
})

# CRITICAL FIX: Only select the features the model was trained on
# Based on your debug output, these are the 10 features:
model_features = ['Close_Ratio_2', 'Trend_2', 'Close_Ratio_5', 'Trend_5', 
                 'Close_Ratio_60', 'Trend_60', 'Close_Ratio_250', 'Trend_250', 
                 'Close_Ratio_1000', 'Trend_1000']

X_test = X_test[model_features]

# Check if we have valid data
if len(X_test) == 0:
    raise ValueError("No valid data after feature engineering")
elif len(X_test) < len(test):
    print(f"Filtered test set from {len(test)} to {len(X_test)} rows")

# Predict and evaluate
y_pred = model.predict(X_test)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.savefig("confusion_matrix.png", dpi=300, bbox_inches='tight')
plt.show()

# Classification Report
print("Classification Report:\n")
print(classification_report(y_true, y_pred))
# Out:
# Filtered test set from 100 to 99 rows
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        40
#            1       0.60      1.00      0.75        59
#
#     accuracy                           0.60        99
#    macro avg       0.30      0.50      0.37        99
# weighted avg       0.36      0.60      0.45        99
# /home/manasvi/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/manasvi/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
plt.savefig("confusion_matrix.png", bbox_inches='tight')
plt.savefig("feature_importances.png", bbox_inches='tight')
